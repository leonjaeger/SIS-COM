# %%
# !pip install twilio==5.7.0
# Out:
# ...
#     100% |████████████████████████████████| 174kB 4.0MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 225kB 11.8MB/s ta 0:00:01
# ...
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b5/99/1d/3626f085ed601453fe4e969340b13d1de5d62c668771c543f2
# ...
#   Stored in directory: /home/jovyan/.cache/pip/wheels/98/82/0d/cfb126a5e40d487157e43fdb3332937713dde36b4d0e1e754d
# Successfully built twilio httplib2
# ...

# %%
from twilio.rest import TwilioRestClient

# %%
TWILIO_PHONE_NUMBER = "+1 206 350 3903";

# %%
DIAL_NUMBERS = ["+59170792340"]

# %%
TWIML_INSTRUCTIONS_URL = \
  "https://vidaenred.org/llamada-Sist_Com.xml"

client = TwilioRestClient("AC0d3de23a67936444d87db59c3c2eecbb", "38d43849ddcc79059fdcb443357e07dc")

# %%
def dial_numbers(numbers_list):

 for number in numbers_list:

  print("Dialing" + number)

  # set the method to “GET” from default POST because Amazon S3 only

  # serves GET requests on files. Typically POST would be used for apps

  client.calls.create(to=number, from_=TWILIO_PHONE_NUMBER,url=TWIML_INSTRUCTIONS_URL, method="GET")

# %%
if __name__ == "__main__":

 dial_numbers(DIAL_NUMBERS)
# Out:
# Dialing+59170792340

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1.- Sirve para que mediante un automata responda al texto predefino al momento de contestar la llamada

# %% [markdown]
# # 2.- se usa para definir el token y el SID con los que se realiza la comunicacion

# %% [markdown]
# # 3.-para marcar los numero que se deseen marcar almacenados en un el array
